# %%
# import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import the dataset
df=pd.read_excel('./python.xlsx')

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
# 9994           Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# rows 9995
# col 13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9995 entries, 0 to 9994
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9995 non-null   object
#  1   Segment       9995 non-null   object
#  2   Country       9995 non-null   object
#  3   City          9995 non-null   object
#  4   State         9995 non-null   object
#  5   Postal Code   9995 non-null   int64
#  6   Region        9995 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9995 non-null   float64
#  10  Quantity      9994 non-null   float64
#  11  Discount      5196 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 1015.2+ KB

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600       2.0
# 1        42420  South        Furniture       Chairs  731.9400       3.0
# 2        90036   West  Office Supplies       Labels   14.6200       2.0
# 3        33311  South        Furniture       Tables  957.5775       5.0
# 4        33311  South  Office Supplies      Storage   22.3680       2.0
#
#    Discount    Profit
# 0       NaN   41.9136
# 1       NaN  219.5820
# 2       NaN    6.8714
# ...

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
# 9994           Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9990        92627   West        Furniture  Furnishings   91.960       2.0
# 9991        92627   West       Technology       Phones  258.576       2.0
# 9992        92627   West  Office Supplies        Paper   29.600       4.0
# 9993        92683   West  Office Supplies   Appliances  243.160       2.0
# 9994        92683   West              NaN          NaN  243.160       NaN
#
#       Discount   Profit
# 9990       NaN  15.6332
# 9991       0.2  19.3932
# ...

# %%
df.isnull().sum()
# Out:
# Ship Mode          0
# Segment            0
# Country            0
# City               0
# State              0
# Postal Code        0
# Region             0
# Category           1
# Sub-Category       1
# Sales              0
# Quantity           1
# Discount        4799
# Profit             1
# dtype: int64

# %%
df.shape
# Out:
# (9995, 13)

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
# 9994           Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600       2.0
# 1        42420  South        Furniture       Chairs  731.9400       3.0
# 2        90036   West  Office Supplies       Labels   14.6200       2.0
# 3        33311  South        Furniture       Tables  957.5775       5.0
# 4        33311  South  Office Supplies      Storage   22.3680       2.0
#
#    Discount    Profit
# 0       NaN   41.9136
# 1       NaN  219.5820
# 2       NaN    6.8714
# ...

# %%
new_df = df.drop(columns = "Sales")
new_df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
# 9994           Class   Consumer  United States      Westminster  California
#
# ...

# %%
new_df["Discount"].fillna(new_df["Discount"].mode()[0], inplace=True)
new_df["Discount"] = new_df["Discount"].astype(str)
new_df["Discount"] = new_df["Discount"].str.replace("mode", "NaN")
new_df["Discount"].head()
# Out:
# 0     0.2
# 1     0.2
# 2     0.2
# 3    0.45
# 4     0.2
# Name: Discount, dtype: object

# %%
# Drop rows with any null values
df_filtered = df.dropna(axis=0, how="any")

# Drop rows with less than 6 non-null values
df_filtered = df.dropna(axis=0, thresh=6)

# Print the filtered DataFrame
print(df_filtered)
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
# 9994           Class   Consumer  United States      Westminster  California
#
# ...

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
# 9994           Class   Consumer  United States      Westminster  California
#
# ...

# %%
#DATA VISUALISATION
list1=['Furniture','Furniture','Furniture','Table','Light']
x=pd.Series(list1)

# %%
x=df.Category.value_counts()

# %%
#disk plot _use of trend lines plt- used for matplot lib ,sns- is used for seaborn
#disk plot is refined grph of histogram
#box plot and violin plot- both are for outliers

# %%
sns.boxplot(df['Quantity'])
# Out:
# <Axes: ylabel='Quantity'>

# %%
#this depictsonly for the particualr outliers are present or not
#frequency of outliers -violin plot predicts outliers anf frequency

# %%
#competed univarient

# %%
#Univarient(1 col)
#Bivarirent( 2 col)
#Multivarient (more than 2 col)
#countplot,box plot,scatter plot

# %%
# cat-numerical- bar graph
#cat-cat-countplot
#num-num-scattterplot

# %%
df['Segment'] = pd.to_numeric(df['Segment'])
df['Segment_numeric'] = df['Segment'].map({'First Class': 1, 'Second Class': 2, 'Third Class': 3})
sns.heatmap(hue='Segment_numeric', data=df)
sns.catplot(x='Segment', y='Survived', data=df, kind='heatmap')

# %%
sns.pairplot(hue='Segment', data=df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9995 entries, 0 to 9994
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9995 non-null   object
#  1   Segment       9995 non-null   object
#  2   Country       9995 non-null   object
#  3   City          9995 non-null   object
#  4   State         9995 non-null   object
#  5   Postal Code   9995 non-null   int64
#  6   Region        9995 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9995 non-null   float64
#  10  Quantity      9994 non-null   float64
#  11  Discount      5196 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 1015.2+ KB

# %%
sns.countplot(y='Category', hue='Segment', data=df)

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
# 9994           Class   Consumer  United States      Westminster  California
#
# ...
